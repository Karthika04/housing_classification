# %%
# ============================================================================
# CELL 1: Install DagsHub
# ============================================================================
# !pip install dagshub mlflow
# Out:
# Requirement already satisfied: dagshub in /opt/anaconda3/lib/python3.13/site-packages (0.6.4)
# Requirement already satisfied: mlflow in /opt/anaconda3/lib/python3.13/site-packages (2.22.4)
# Requirement already satisfied: PyYAML>=5 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (6.0.2)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (1.4.4)
# Requirement already satisfied: click>=8.0.4 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (8.1.8)
# Requirement already satisfied: httpx>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (0.28.1)
# Requirement already satisfied: GitPython>=3.1.29 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (3.1.43)
# Requirement already satisfied: rich>=13.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (13.9.4)
# Requirement already satisfied: dacite~=1.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (1.6.0)
# Requirement already satisfied: tenacity>=8.2.2 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (9.0.0)
# Requirement already satisfied: gql[requests] in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (4.0.0)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (0.6.7)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (2.2.2)
# Requirement already satisfied: treelib>=1.6.4 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (1.8.0)
# Requirement already satisfied: pathvalidate>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (3.3.1)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (2.9.0.post0)
# Requirement already satisfied: boto3 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (1.42.12)
# Requirement already satisfied: semver in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (3.0.2)
# Requirement already satisfied: dagshub-annotation-converter>=0.1.12 in /opt/anaconda3/lib/python3.13/site-packages (from dagshub) (0.1.15)
# Requirement already satisfied: mlflow-skinny==2.22.4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (2.22.4)
# Requirement already satisfied: Flask<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (1.16.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (2.3.5)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow) (2.0.39)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (5.5.1)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (0.74.0)
# Requirement already satisfied: fastapi<1 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (0.124.4)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (1.39.1)
# Requirement already satisfied: packaging<25 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (6.33.2)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (2.12.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==2.22.4->mlflow) (0.38.0)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.3)
# Requirement already satisfied: google-auth~=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.4->mlflow) (2.45.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==2.22.4->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==2.22.4->mlflow) (0.0.4)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from GitPython>=3.1.29->dagshub) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.29->dagshub) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.4->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.4->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.4->mlflow) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/anaconda3/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.4->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->dagshub) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->dagshub) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.4->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.4->mlflow) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.4->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil->dagshub) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.4->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.4->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.4->mlflow) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.4->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/lib/python3.13/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.4->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.4->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==2.22.4->mlflow) (0.16.0)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.13/site-packages (from dagshub-annotation-converter>=0.1.12->dagshub) (5.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.23.0->dagshub) (1.0.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.1.0->dagshub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.1.0->dagshub) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->dagshub) (0.1.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.12 in /opt/anaconda3/lib/python3.13/site-packages (from boto3->dagshub) (1.42.12)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from boto3->dagshub) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from boto3->dagshub) (0.16.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.13/site-packages (from dataclasses-json->dagshub) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from dataclasses-json->dagshub) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (1.0.0)
# Requirement already satisfied: yarl<2.0,>=1.6 in /opt/anaconda3/lib/python3.13/site-packages (from gql[requests]->dagshub) (1.18.0)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in /opt/anaconda3/lib/python3.13/site-packages (from gql[requests]->dagshub) (2.2.1)
# Requirement already satisfied: requests_toolbelt<2,>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from gql[requests]->dagshub) (1.0.0)
# Requirement already satisfied: multidict>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (0.3.1)

# %%
# ============================================================================
# CELL 2: Setup DagsHub
# ============================================================================
import dagshub
import mlflow
import pandas as pd
from pathlib import Path

# Initialize DagsHub - REPLACE WITH YOUR USERNAME
DAGSHUB_USERNAME = "karthikaon0412"  # <-- CHANGE THIS
DAGSHUB_REPO = "housing_fall2025"

print(f"Initializing DagsHub...")
print(f"Repository: {DAGSHUB_USERNAME}/{DAGSHUB_REPO}")

dagshub.init(repo_owner=DAGSHUB_USERNAME, repo_name=DAGSHUB_REPO, mlflow=True)

mlflow.set_experiment("housing_price_classification")

print("✅ DagsHub initialized")
print(f"🔗 View at: https://dagshub.com/{DAGSHUB_USERNAME}/{DAGSHUB_REPO}")
# Out:
# Initializing DagsHub...
# Repository: karthikaon0412/housing_fall2025
# Initialized MLflow to track repo "karthikaon0412/housing_fall2025"
# Repository karthikaon0412/housing_fall2025 initialized!
# ✅ DagsHub initialized
# 🔗 View at: https://dagshub.com/karthikaon0412/housing_fall2025

# %%
# ============================================================================
# CELL 3: Log All Experiments
# ============================================================================
models_path = Path('/Users/karthika/housing_app_fall25/api/models')
results_df = pd.read_csv(models_path / 'experiment_results.csv')

print(f"\n{'='*70}")
print(f"Logging {len(results_df)} experiments to DagsHub...")
print(f"{'='*70}\n")

for idx, row in results_df.iterrows():
    experiment_name = row['experiment_name']
    
    print(f"[{idx+1}/{len(results_df)}] Logging: {experiment_name}")
    
    with mlflow.start_run(run_name=experiment_name):
        # Log parameters
        mlflow.log_param("model_type", row['model_type'])
        mlflow.log_param("pca", row['pca'])
        mlflow.log_param("optuna", row['optuna'])
        mlflow.log_param("experiment_name", experiment_name)
        
        # Log metrics
        mlflow.log_metric("f1_score", row['f1_score'])
        mlflow.log_metric("f1_score_percentage", row['f1_score'] * 100)
        
        # Log model file if it exists
        model_path = models_path / f"{experiment_name}.pkl"
        if model_path.exists():
            mlflow.log_artifact(str(model_path), artifact_path="models")
        
        # Log tags
        mlflow.set_tag("model_family", row['model_type'])
        mlflow.set_tag("preprocessing", "PCA" if row['pca'] else "No PCA")
        mlflow.set_tag("tuning", "Optuna" if row['optuna'] else "No Tuning")
        
        print(f"   ✅ F1 Score: {row['f1_score']:.4f}")

print(f"\n{'='*70}")
print("✅ All experiments logged to DagsHub!")
print(f"{'='*70}")
print(f"\n🔗 View your experiments at:")
print(f"   https://dagshub.com/{DAGSHUB_USERNAME}/{DAGSHUB_REPO}")
# Out:
# ======================================================================
# Logging 16 experiments to DagsHub...
# ======================================================================
#
# [1/16] Logging: RandomForest_NoPCA_Optuna
#    ✅ F1 Score: 0.8203
# 🏃 View run RandomForest_NoPCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/5edf3c2ea5c5465bb5650f3992749c46
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [2/16] Logging: XGBoost_NoPCA_Optuna
#    ✅ F1 Score: 0.8188
# 🏃 View run XGBoost_NoPCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/2e62a494f9824a1cad497e9272eb830a
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [3/16] Logging: RandomForest_NoPCA_NoOptuna
#    ✅ F1 Score: 0.8073
# 🏃 View run RandomForest_NoPCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/3774edde537949518453d1114ca99ec0
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [4/16] Logging: LightGBM_NoPCA_NoOptuna
#    ✅ F1 Score: 0.8006
# 🏃 View run LightGBM_NoPCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/cefe7f9e171f43e2bd1d0e3b12d9f030
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [5/16] Logging: LightGBM_NoPCA_Optuna
#    ✅ F1 Score: 0.8005
# 🏃 View run LightGBM_NoPCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/57f5f29c1f2b409cae576f2c0809d04e
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [6/16] Logging: XGBoost_NoPCA_NoOptuna
#    ✅ F1 Score: 0.8001
# 🏃 View run XGBoost_NoPCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/034b58bce2d545ba9e35bd1317c4f552
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [7/16] Logging: GradientBoosting_NoPCA_NoOptuna
#    ✅ F1 Score: 0.7957
# 🏃 View run GradientBoosting_NoPCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/cf68e319b559475c96531a2827e1a6ba
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [8/16] Logging: GradientBoosting_NoPCA_Optuna
#    ✅ F1 Score: 0.7942
# 🏃 View run GradientBoosting_NoPCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/7448c4e0640347428ba0f6fa91d2bac6
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [9/16] Logging: LightGBM_PCA_NoOptuna
#    ✅ F1 Score: 0.7828
# 🏃 View run LightGBM_PCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/a6a430d81a5545929cf21354e875ae2a
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [10/16] Logging: LightGBM_PCA_Optuna
#    ✅ F1 Score: 0.7812
# 🏃 View run LightGBM_PCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/8e50a328e35f4775a678ab932db751f4
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [11/16] Logging: XGBoost_PCA_Optuna
#    ✅ F1 Score: 0.7804
# 🏃 View run XGBoost_PCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/2bb7219918bc4871a1b89aaf069b9314
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [12/16] Logging: GradientBoosting_PCA_Optuna
#    ✅ F1 Score: 0.7794
# 🏃 View run GradientBoosting_PCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/df5018f9e64947d2a003cc7411868caa
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [13/16] Logging: GradientBoosting_PCA_NoOptuna
#    ✅ F1 Score: 0.7780
# 🏃 View run GradientBoosting_PCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/9ffc0e826ee44b56a222fe951c88914d
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [14/16] Logging: XGBoost_PCA_NoOptuna
#    ✅ F1 Score: 0.7766
# 🏃 View run XGBoost_PCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/92b157e825d246809c2e9ae3ff43c57e
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [15/16] Logging: RandomForest_PCA_NoOptuna
#    ✅ F1 Score: 0.7662
# 🏃 View run RandomForest_PCA_NoOptuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/7f403c968e7b4ba98a1580485fce894b
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
# [16/16] Logging: RandomForest_PCA_Optuna
#    ✅ F1 Score: 0.7618
# 🏃 View run RandomForest_PCA_Optuna at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/54b118ab28cc4552964103fee4316cc1
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
#
# ======================================================================
# ✅ All experiments logged to DagsHub!
# ======================================================================
#
# 🔗 View your experiments at:
#    https://dagshub.com/karthikaon0412/housing_fall2025

# %%
# ============================================================================
# CELL 4: Log Best Model Information
# ============================================================================
best_model = results_df.loc[results_df['f1_score'].idxmax()]

print(f"\n{'='*70}")
print("BEST MODEL SUMMARY")
print(f"{'='*70}")
print(f"Model: {best_model['experiment_name']}")
print(f"Type: {best_model['model_type']}")
print(f"F1 Score: {best_model['f1_score']:.4f}")
print(f"PCA: {best_model['pca']}")
print(f"Optuna: {best_model['optuna']}")
print(f"{'='*70}")

# Log summary
with mlflow.start_run(run_name="BEST_MODEL_SUMMARY"):
    mlflow.log_param("best_model", best_model['experiment_name'])
    mlflow.log_metric("best_f1_score", best_model['f1_score'])
    mlflow.log_metric("average_f1_score", results_df['f1_score'].mean())
    mlflow.log_metric("std_f1_score", results_df['f1_score'].std())
    
    # Log experiment results CSV
    mlflow.log_artifact(str(models_path / 'experiment_results.csv'))

print("\n✅ DagsHub integration complete!")
# Out:
# ======================================================================
# BEST MODEL SUMMARY
# ======================================================================
# Model: RandomForest_NoPCA_Optuna
# Type: RandomForest
# F1 Score: 0.8203
# PCA: False
# Optuna: True
# ======================================================================
# 🏃 View run BEST_MODEL_SUMMARY at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2/runs/f5078d747f164bd2b47d4bccef574895
# 🧪 View experiment at: https://dagshub.com/karthikaon0412/housing_fall2025.mlflow/#/experiments/2
#
# ✅ DagsHub integration complete!
